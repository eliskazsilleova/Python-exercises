# %%
import pandas as pd 
import requests 

url = "https://storage.googleapis.com/kagglesdsdata/datasets/6908893/11084864/Female%20infertility.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260210%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260210T231550Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
file_name = "Female infertility.csv"
r = requests.get(url)
with open ("Female infertility.csv", "wb") as f:
    f.write(r.content)

df = pd.read_csv(file_name)
return df
# Out:
# First 5 rows of the dataset:
#    Patient ID  Age  Ovulation Disorders  Blocked Fallopian Tubes  \
# 0           1   32                    1                        0
# 1           2   28                    0                        1
# 2           3   35                    1                        0
# 3           4   30                    0                        1
# 4           5   33                    1                        0
#
#    Endometriosis  Uterine Abnormalities  Pelvic Inflammatory Disease  \
# 0              1                      0                            0
# 1              0                      1                            0
# 2              1                      0                            1
# 3              0                      1                            0
# 4              0                      0                            0
#
#    Hormonal Imbalances  Premature Ovarian Insufficiency  Autoimmune Disorders  \
# ...

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.1 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 13.1 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...

# %%
# !pip install requests
